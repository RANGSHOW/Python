# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as display
import sklearn.model_selection as train_test_split

# %%
from datetime import datetime

# %%
today = datetime(2020, 4, 18)

# %%
ap_stk = pd.read_csv('data/apple_stock.csv')

# %%
ex_df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]],
                    index=['r0', 'r1', 'r2'],
                    columns=['c0', 'c1', 'c2'])

# %%
num_df = pd.DataFrame(np.arange(1, 10).reshape(3, 3), index=['Alpha', 'Bravo', 'Charlie'], columns = ['A', 'B', 'C'])

# %%
#1.
df = pd.read_csv('data/apple_stock.csv')
df['Date'] = df['Date'].apply(pd.to_datetime)
df.set_index('Date', inplace=True)
df.index
# Out:
# Int64Index([2009, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010,
#             ...
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
#            dtype='int64', name='Date', length=2265)

# %%
#2.
df = pd.read_csv('data/apple_stock.csv', index_col='Date')
df.index = pd.to_datetime(df.index)
df.index
# Out:
# Int64Index([12,  1,  1,  1,  1,  1,  1,  1,  1,  1,
#             ...
#             12, 12, 12, 12, 12, 12, 12, 12, 12, 12],
#            dtype='int64', name='Date', length=2265)

# %%
df.index.month
# Out:
# Int64Index([12,  1,  1,  1,  1,  1,  1,  1,  1,  1,
#             ...
#             12, 12, 12, 12, 12, 12, 12, 12, 12, 12],
#            dtype='int64', name='Date', length=2265)

# %%
df['Close']['2015':].resample('M').mean().plot(figsize=(20,8))

# %%
daily_date_range = pd.date_range(start=datetime(2017,1,1),
                               end=datetime(2019,1,24),
                               )
daily_dataset = pd.DataFrame(
    data={'value': np.random.rand(len(daily_date_range))},
    index=daily_date_range)

# %%
daily_dataset

# %%
df['Close: 20Day Mean'] = df['Close'].rolling(20).mean()
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2009-12-31   30.478571   30.080000   30.447144   30.104286   88102700.0
# 2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# ...                ...         ...         ...         ...          ...
# 2018-12-24  151.550003  146.589996  148.149994  146.830002   37169200.0
# 2018-12-26  157.229996  146.720001  148.300003  157.169998   58582500.0
# 2018-12-27  156.770004  150.070007  155.839996  156.149994   53117100.0
# 2018-12-28  158.520004  154.550003  157.500000  156.229996   42291400.0
# 2018-12-31  159.360001  156.479996  158.529999  157.740005   35003500.0
#
#              Adj Close  Close: 20Day Mean
# Date
# 2009-12-31   20.159719                NaN
# ...

# %%
df['Close: 20Day Mean']['2010-01-20':]
# Out:
# Date
# 2010-01-20           NaN
# 2010-01-21           NaN
# 2010-01-22           NaN
# 2010-01-25           NaN
# 2010-01-26           NaN
#                  ...
# 2018-12-24    169.085002
# 2018-12-26    168.212502
# 2018-12-27    167.308002
# 2018-12-28    166.072501
# 2018-12-31    164.982001
# Name: Close: 20Day Mean, Length: 2253, dtype: float64
